# %% [markdown]
# ## Lecture 2 - Linear Regression and Gradient Descent

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read data
# https://www.kaggle.com/datasets/syuzai/perth-house-prices
df = pd.read_csv("../data/all_perth_310121.csv")
df.head(100)
# Out:
#                 ADDRESS           SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0         1 Acorn Place       South Lake  565000         4          2     2.0
# 1           1 Addis Way            Wandi  365000         3          2     2.0
# 2       1 Ainsley Court          Camillo  287000         3          1     1.0
# 3       1 Albert Street         Bellevue  255000         2          1     2.0
# 4          1 Aman Place        Lockridge  325000         4          1     2.0
# ..                  ...              ...     ...       ...        ...     ...
# 95      1 Clifford Loop            Darch  492000         3          2     2.0
# 96    1 Cliverton Court          Marmion  974000         5          2     2.0
# 97  1 Clovertree Street       Maddington  435000         4          2     5.0
# 98        1 Cobea Court  Mount Claremont  900000         3          2     2.0
# 99       1 Cockman Road        Greenwood  405000         3          1     3.0
#
#     LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0         600         160      2003.0     18300  Cockburn Central Station
# 1         351         139      2013.0     26900           Kwinana Station
# 2         719          86      1979.0     22600           Challis Station
# 3         651          59      1953.0     17900           Midland Station
# 4         466         131      1998.0     11200        Bassendean Station
# ..        ...         ...         ...       ...                       ...
# 95        289         122      2008.0     15100         Greenwood Station
# 96        766         290      1990.0     15200           Warwick Station
# 97       1062         177      1988.0     17800          Gosnells Station
# 98        367         160      1995.0      6900       Loch Street Station
# 99        698         110      1975.0     13900           Warwick Station
#
#     NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# 0               1800  09-2018\r      6164 -32.115900  115.842450
# 1               4900  02-2019\r      6167 -32.193470  115.859554
# 2               1900  06-2015\r      6111 -32.120578  115.993579
# 3               3600  07-2018\r      6056 -31.900547  116.038009
# 4               2000  11-2016\r      6054 -31.885790  115.947780
# ..               ...        ...       ...        ...         ...
# 95              6100  04-2016\r      6065 -31.817020  115.848110
# 96              3600  02-2013\r      6020 -31.845840  115.758090
# 97              2000  09-2017\r      6109 -32.054100  116.004300
# 98               640  06-2017\r      6010 -31.966900  115.787780
# 99              2100  08-2018\r      6024 -31.833500  115.813620
#
#                      NEAREST_SCH  NEAREST_SCH_DIST  NEAREST_SCH_RANK
# 0    LAKELAND SENIOR HIGH SCHOOL          0.828339               NaN
# 1                 ATWELL COLLEGE          5.524324             129.0
# 2   KELMSCOTT SENIOR HIGH SCHOOL          1.649178             113.0
# 3   SWAN VIEW SENIOR HIGH SCHOOL          1.571401               NaN
# 4                  KIARA COLLEGE          1.514922               NaN
# ..                           ...               ...               ...
# 95     ASHDALE SECONDARY COLLEGE          0.866780              75.0
# 96     CARINE SENIOR HIGH SCHOOL          1.857117              47.0
# 97         LUMEN CHRISTI COLLEGE          1.645874             122.0
# 98            JOHN XXIII COLLEGE          0.825897               8.0
# 99    WARWICK SENIOR HIGH SCHOOL          0.600502               NaN
#
# [100 rows x 19 columns]

# %%
X, y = df["LAND_AREA"].to_numpy(), df["PRICE"].to_numpy()

# %%
plt.scatter(X, y, alpha=0.5)
plt.xlabel("Land area")
plt.ylabel("Price")
plt.show()
